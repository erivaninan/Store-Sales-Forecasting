# %% [markdown]
# ---
#
# ## LSTM multicouches

# %% [markdown]
# ---
#
# ## Avantages
# 1. **Capture des tendances :** Les LSTM mémorisent les variations saisonnières et les tendances à long terme dans les données de ventes.
# 2. **Gestion des dépendances temporelles :** Adaptés pour modéliser les relations entre les ventes passées et futures.
# 3. **Précision :** Gèrent les séries temporelles complexes, comme les variations dues à des événements spécifiques (soldes, fêtes).
# 4. **Flexibilité :** Fonctionnent avec des données multivariées (e.g., météo, promotions) pour des prévisions plus précises.

# %%
import pandas as pd
import numpy as np
import plotly_express as px
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import SGD
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from useful_functions import *
file_path = "./results.json"

# %%
# --Tables--
series_train = pd.read_csv("series_train.csv")
series_test = pd.read_csv("series_test.csv")

# %%
dataset_train = series_train['sales'].values.reshape(-1, 1)
dataset_test = series_test['sales'].values.reshape(-1, 1)


scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train = scaler.fit_transform(dataset_train)
scaled_test = scaler.transform(dataset_test)

# %% [markdown]
# Pour les réseaux de neurones, il est essentiel de normaliser les données avec `MinMaxScaler` afin de :
# - Accélérer la convergence de l'entraînement (pour adam).
# - Éviter que des caractéristiques avec des plages de valeurs très différentes n'influencent de manière disproportionnée les poids du modèle.
#
# La mise à l'échelle Min-Max redimensionne les données dans une plage spécifiée, généralement entre 0 et 1, en utilisant la formule suivante :
#
# $$
# x_{\text{scaled}} = \frac{x - x_{\min}}{x_{\max} - x_{\min}}
# $$
#
# où :
# - $x$ : la valeur initiale d'une caractéristique.
# - $x_{\min}$ et $x_{\max}$ : les valeurs minimale et maximale de la caractéristique.
# - $x_{\text{scaled}}$ : la valeur normalisée, comprise entre 0 et 1.

# %%
lag_size = 7 #h=0, on a pas de retard sur les données, 7 trouvé dans le module Sarimax avec analsye acf pacf
X_train, y_train, X_test, y_test = [], [], [], []

# --training--
for i in range(lag_size, len(scaled_train)):
    X_train.append(scaled_train[i - lag_size:i, 0])
    y_train.append(scaled_train[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# --testing--
for i in range(lag_size, len(scaled_test)):
    X_test.append(scaled_test[i - lag_size:i, 0])
    y_test.append(scaled_test[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)

# %% [markdown]
#  ### Explication du reshape dans les séries temporelles
#
# Lorsqu'on utilise des modèles séquentiels comme les LSTM ou GRU, les données doivent être formatées correctement. Les modèles attendent en entré les données sous la forme suivante :
#
# $$
# (n_{\text{samples}}, \text{timesteps}, \text{features})
# $$
#
# ##### Reshape de `X_test`, $(n_{\text{samples}}, \text{lag\_size})$ --> $(n_{\text{samples}}, \text{timesteps}, \text{features})$

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# initializing the LSTM
regressorLSTM = Sequential()
 
#Adding LSTM layers
regressorLSTM.add(LSTM(units=256,#bcp de neuronne car données pas lineaire, un peu compliqué
                       activation = 'tanh' ,#pour données symetrique c'est bien
                       return_sequences = True, 
                       input_shape = (X_train.shape[1],1)))
regressorLSTM.add(Dropout(0.2))
regressorLSTM.add(LSTM(units=128,#bcp de neuronne car données pas lineaire, un peu compliqué
                       activation = 'tanh' ,#pour données symetrique c'est bien
                       return_sequences = True, 
                       input_shape = (X_train.shape[1],1)))
regressorLSTM.add(Dropout(0.2))
regressorLSTM.add(LSTM(units=64,#bcp de neuronne car données pas lineaire, un peu compliqué
                       activation = 'tanh' ,#pour données symetrique c'est bien
                       return_sequences = False, 
                       input_shape = (X_train.shape[1],1)))
regressorLSTM.add(Dropout(0.2))
#Adding the output layer
regressorLSTM.add(Dense(50))
regressorLSTM.add(Dense(1))
 
#Compiling the model
regressorLSTM.compile(optimizer = 'adam',
                      loss = 'mean_squared_error',
                      metrics = ["accuracy"])
 
#Fitting the model
regressorLSTM.fit(X_train,y_train,
              batch_size=32,
              epochs=50,
              validation_split=0.2
              )
regressorLSTM.summary()
# Out:
# Epoch 1/50
# 27/27 [==============================] - 5s 80ms/step - loss: 0.0109 - accuracy: 0.0012 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0054 - accuracy: 0.0012 - val_loss: 0.0152 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0047 - accuracy: 0.0012 - val_loss: 0.0103 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0042 - accuracy: 0.0012 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0042 - accuracy: 0.0012 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0043 - accuracy: 0.0012 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0042 - accuracy: 0.0012 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0039 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0040 - accuracy: 0.0012 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0041 - accuracy: 0.0012 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0040 - accuracy: 0.0012 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0040 - accuracy: 0.0012 - val_loss: 0.0095 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0039 - accuracy: 0.0012 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0040 - accuracy: 0.0012 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0039 - accuracy: 0.0012 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0042 - accuracy: 0.0012 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0035 - accuracy: 0.0012 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0035 - accuracy: 0.0012 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 27/27 [==============================] - 1s 40ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0107 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0037 - accuracy: 0.0012 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0038 - accuracy: 0.0012 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0034 - accuracy: 0.0012 - val_loss: 0.0091 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0036 - accuracy: 0.0012 - val_loss: 0.0080 - val_accuracy: 0.0000e+00
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 256)            264192
#
#  dropout (Dropout)           (None, 7, 256)            0
#
#  lstm_1 (LSTM)               (None, 7, 128)            197120
#
#  dropout_1 (Dropout)         (None, 7, 128)            0
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 50)                3250
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 514021 (1.96 MB)
# Trainable params: 514021 (1.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Testing

# %%
test_loss = regressorLSTM.evaluate(X_test, y_test)
print("Test Loss:", test_loss)

train_predictions = regressorLSTM.predict(X_train)
test_predictions = regressorLSTM.predict(X_test)

# Inversion de la normalisation
train_predictions_inversed = scaler.inverse_transform(train_predictions)
test_predictions_inversed = scaler.inverse_transform(test_predictions)


series_train['train_Forecast_LSTM'] = np.nan
series_train.loc[lag_size:, 'train_Forecast_LSTM'] = train_predictions_inversed.flatten()

series_test['test_Forecast_LSTM'] = np.nan
series_test.loc[lag_size:, 'test_Forecast_LSTM'] = test_predictions_inversed.flatten()
# Out:
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.0000e+00
# Test Loss: [0.0160308089107275, 0.0]
# 34/34 [==============================] - 1s 5ms/step
# 19/19 [==============================] - 0s 5ms/step

# %%
fig = px.line(series_train, x='date', y=['sales', 'train_Forecast_LSTM'],title="Predictions du train")
fig.show()

# %%
fig = px.line(series_test, x='date', y=['sales', 'test_Forecast_LSTM'],title="Predictions du test")
fig.show()

# %%
nrmse, mape, mae,r2 = calculate_metrics(series_test.loc[lag_size:, 'sales'], series_test.loc[lag_size:, 'test_Forecast_LSTM'])
print(nrmse)
print(mape)
print(mae)
print(r2)
# Out:
# 0.08788111865753488
# 5.05838639666586e+19
# 171320.50213796174
# 0.0524269958610154

# %% [markdown]
# ```python
# save_model_results(
#     file_path=file_path,
#     model_name="LSTM_multicouches",
#     params="3couches lstm 3 dropout" ,
#     nrmse=nrmse,
#     mape=mape,
#     mae=mae,
#     r2=r2
# )
# ```

# %%
#series_train.to_csv("series_train",index =False, header=True)
#series_test.to_csv("series_test",index =False, header=True)
